# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = 'https://www.newchic.com/slippers-c-3619/?country=63&conversionType=US&from=nav'
html = urlopen(url)

# %%
soup = BeautifulSoup(html)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_86\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_86\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
data_name = soup.findAll('p', class_='wom_lst_name ellipsis')
data_name
# Out:
# [<p class="wom_lst_name ellipsis">
#  <a href="https://www.newchic.com/slippers-3619/p-1541508.html?rmmds=category" target="_blank" title="Men Light Weight Soft Beach Slippers">Men Light Weight Soft Beach Slippers</a>
#  </p>, <p class="wom_lst_name ellipsis">
#  <a href="https://www.newchic.com/mens-sandals-4188/p-1541509.html?rmmds=category" target="_blank" title="Men Non Slip Beach Casual Leather Sandals">Men Non Slip Beach Casual Leather Sandals</a>
#  </p>, <p class="wom_lst_name ellipsis">
#  <a href="https://www.newchic.com/slippers-3619/p-1541505.html?rmmds=category" target="_blank" title="Men Clip Toe Soft Casual Beach Slippers ">Men Clip Toe Soft Casual Beach Slippers </a>
#  </p>, <p class="wom_lst_name ellipsis">
#  <a href="https://www.newchic.com/slippers-3619/p-1541494.html?rmmds=category" target="_blank" title="Men Light Weight Casual Beach Slippers">Men Light Weight Casual Beach Slippers</a>
#  </p>, <p class="wom_lst_name ellipsis">
# ...

# %%
## Clean Data ##
import re
Names = []
for li in data_name:
    str_name = str(li)
    pattern = '<.*?>'
    clean_name = re.sub(pattern, '', str_name)
    Names.append(clean_name)
Names
# Out:
# ['\nMen Light Weight Soft Beach Slippers\n',
#  '\nMen Non Slip Beach Casual Leather Sandals\n',
#  '\nMen Clip Toe Soft Casual Beach Slippers \n',
#  '\nMen Light Weight Casual Beach Slippers\n',
#  '\nMen Stylish Soft Casual Beach Slippers \n',
#  '\nMen Light Weight Soft Beach Slippers\n',
#  '\nUREVO\nUREVO Flip Flops Summer Beach Slippers\n',
#  '\nMen Light Weight Casual Beach Slippers \n',
#  '\nMen Water Beach Soft Flip Flops\n',
#  '\nMen Colorful Printing Graffiti Slippers\n',
#  '\nMen Colorful Printing Beach Slippers\n',
#  '\nMen Colorful Printing Graffiti Beach Slippers\n',
#  '\nMen Colorful Comfy Non Slip Flip Flops\n',
#  '\nMen Colorful Non Slip Flip Flops \n',
#  '\nMen Leather Splcing Comfy Flip Flops\n',
#  '\nMen Light Weight Soft Beach Flip Flops\n',
#  '\n Menico\nMenico Men Retro Comfy Casual Beach Slippers \n',
#  '\n Menico\nMenico Men Retro Leather Comfy Beach Slippers\n',
#  '\nMen Oil Leather Toe Protective Water Slippers\n',
# ...

# %%
x = pd.Index(range(175,210))
print(x)
# Out:
# RangeIndex(start=175, stop=210, step=1)

# %%
df = pd.DataFrame(Names,index=x)
df.head()
# Out:
#                                                  0
# 175       \nMen Light Weight Soft Beach Slippers\n
# 176  \nMen Non Slip Beach Casual Leather Sandals\n
# 177   \nMen Clip Toe Soft Casual Beach Slippers \n
# 178     \nMen Light Weight Casual Beach Slippers\n
# 179    \nMen Stylish Soft Casual Beach Slippers \n

# %%
df[0] = df[0].str.strip('\n')
df.head()
# Out:
#                                              0
# 175       Men Light Weight Soft Beach Slippers
# 176  Men Non Slip Beach Casual Leather Sandals
# 177   Men Clip Toe Soft Casual Beach Slippers
# 178     Men Light Weight Casual Beach Slippers
# 179    Men Stylish Soft Casual Beach Slippers

# %%
df.rename(columns={0:'Names'}, inplace=True)

# %%
df['Names'].replace('\n','', regex=True, inplace=True)
df
# Out:
#                                                  Names
# 175               Men Light Weight Soft Beach Slippers
# 176          Men Non Slip Beach Casual Leather Sandals
# 177           Men Clip Toe Soft Casual Beach Slippers
# 178             Men Light Weight Casual Beach Slippers
# 179            Men Stylish Soft Casual Beach Slippers
# 180               Men Light Weight Soft Beach Slippers
# 181        UREVOUREVO Flip Flops Summer Beach Slippers
# 182            Men Light Weight Casual Beach Slippers
# 183                    Men Water Beach Soft Flip Flops
# 184            Men Colorful Printing Graffiti Slippers
# 185               Men Colorful Printing Beach Slippers
# 186      Men Colorful Printing Graffiti Beach Slippers
# 187             Men Colorful Comfy Non Slip Flip Flops
# 188                  Men Colorful Non Slip Flip Flops
# 189               Men Leather Splcing Comfy Flip Flops
# 190             Men Light Weight Soft Beach Flip Flops
# ...

# %%
data_price = soup.findAll('span', class_='price product-price-js')
data_price
# Out:
# [<span class="price product-price-js" oriprice="22.08" rule_final_price="">371.16E£</span>,
#  <span class="price product-price-js" oriprice="19.99" rule_final_price="">336.03E£</span>,
#  <span class="price product-price-js" oriprice="27.44" rule_final_price="">461.27E£</span>,
#  <span class="price product-price-js" oriprice="19.99" rule_final_price="">336.03E£</span>,
#  <span class="price product-price-js" oriprice="34.2" rule_final_price="">574.90E£</span>,
#  <span class="price product-price-js" oriprice="27.44" rule_final_price="">461.27E£</span>,
#  <span class="price product-price-js" oriprice="10.99" rule_final_price="">184.74E£</span>,
#  <span class="price product-price-js" oriprice="14.93" rule_final_price="">250.97E£</span>,
#  <span class="price product-price-js" oriprice="18.57" rule_final_price="">312.16E£</span>,
#  <span class="price product-price-js" oriprice="28.79" rule_final_price="">483.96E£</span>,
# ...

# %%
## Clean Data ##
import re
Prices = []
for li in data_price:
    str_name = str(li)
    pattern = '<.*?>'
    clean_name = re.sub(pattern, '', str_name)
    Prices.append(clean_name)
Prices
# Out:
# ['371.16E£',
#  '336.03E£',
#  '461.27E£',
#  '336.03E£',
#  '574.90E£',
#  '461.27E£',
#  '184.74E£',
#  '250.97E£',
#  '312.16E£',
#  '483.96E£',
#  '478.58E£',
#  '490.01E£',
#  '595.91E£',
#  '496.57E£',
#  '580.11E£',
#  '289.97E£',
#  '561.96E£',
#  '561.96E£',
#  '768.72E£',
#  '504.13E£',
#  '480.60E£',
#  '488.67E£',
#  '521.61E£',
#  '367.63E£',
#  '461.10E£',
#  '395.20E£',
#  '411.68E£',
#  '477.74E£',
#  '567.50E£',
#  '438.07E£',
#  '465.47E£',
#  '299.39E£',
#  '266.94E£',
#  '327.96E£',
#  '460.26E£']

# %%
df1 = pd.DataFrame(Prices, index=x)
df1
# Out:
#             0
# 175  371.16E£
# 176  336.03E£
# 177  461.27E£
# 178  336.03E£
# 179  574.90E£
# 180  461.27E£
# 181  184.74E£
# 182  250.97E£
# 183  312.16E£
# 184  483.96E£
# 185  478.58E£
# 186  490.01E£
# 187  595.91E£
# 188  496.57E£
# 189  580.11E£
# 190  289.97E£
# 191  561.96E£
# 192  561.96E£
# 193  768.72E£
# 194  504.13E£
# 195  480.60E£
# 196  488.67E£
# 197  521.61E£
# 198  367.63E£
# 199  461.10E£
# 200  395.20E£
# 201  411.68E£
# 202  477.74E£
# 203  567.50E£
# 204  438.07E£
# 205  465.47E£
# 206  299.39E£
# 207  266.94E£
# 208  327.96E£
# 209  460.26E£

# %%
df1.rename(columns={0:'Prices'}, inplace=True)
df1.head()
# Out:
#        Prices
# 175  371.16E£
# 176  336.03E£
# 177  461.27E£
# 178  336.03E£
# 179  574.90E£

# %%
df1['Prices'].replace('E£','', regex=True, inplace=True)
df1
# Out:
#      Prices
# 175  371.16
# 176  336.03
# 177  461.27
# 178  336.03
# 179  574.90
# 180  461.27
# 181  184.74
# 182  250.97
# 183  312.16
# 184  483.96
# 185  478.58
# 186  490.01
# 187  595.91
# 188  496.57
# 189  580.11
# 190  289.97
# 191  561.96
# 192  561.96
# 193  768.72
# 194  504.13
# 195  480.60
# 196  488.67
# 197  521.61
# 198  367.63
# 199  461.10
# 200  395.20
# 201  411.68
# 202  477.74
# 203  567.50
# 204  438.07
# 205  465.47
# 206  299.39
# 207  266.94
# 208  327.96
# 209  460.26

# %%
df1['Prices'].replace(',','',regex=True, inplace=True)
df1.tail()
# Out:
#      Prices
# 205  465.47
# 206  299.39
# 207  266.94
# 208  327.96
# 209  460.26

# %%
df1['Prices'] = pd.to_numeric(df1['Prices'])
df1.tail()
# Out:
#      Prices
# 205  465.47
# 206  299.39
# 207  266.94
# 208  327.96
# 209  460.26

# %%
df_slippers = df.join(df1)
df_slippers
# Out:
#                                                  Names  Prices
# 175               Men Light Weight Soft Beach Slippers  371.16
# 176          Men Non Slip Beach Casual Leather Sandals  336.03
# 177           Men Clip Toe Soft Casual Beach Slippers   461.27
# 178             Men Light Weight Casual Beach Slippers  336.03
# 179            Men Stylish Soft Casual Beach Slippers   574.90
# 180               Men Light Weight Soft Beach Slippers  461.27
# 181        UREVOUREVO Flip Flops Summer Beach Slippers  184.74
# 182            Men Light Weight Casual Beach Slippers   250.97
# 183                    Men Water Beach Soft Flip Flops  312.16
# 184            Men Colorful Printing Graffiti Slippers  483.96
# 185               Men Colorful Printing Beach Slippers  478.58
# 186      Men Colorful Printing Graffiti Beach Slippers  490.01
# 187             Men Colorful Comfy Non Slip Flip Flops  595.91
# 188                  Men Colorful Non Slip Flip Flops   496.57
# ...

# %%
df_slippers.shape
# Out:
# (35, 2)

# %%
df_f = pd.DataFrame({'Type':['Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers','Slippers']},index=x)
df_f
# Out:
#          Type
# 175  Slippers
# 176  Slippers
# 177  Slippers
# 178  Slippers
# 179  Slippers
# 180  Slippers
# 181  Slippers
# 182  Slippers
# 183  Slippers
# 184  Slippers
# 185  Slippers
# 186  Slippers
# 187  Slippers
# 188  Slippers
# 189  Slippers
# 190  Slippers
# 191  Slippers
# 192  Slippers
# 193  Slippers
# 194  Slippers
# 195  Slippers
# 196  Slippers
# 197  Slippers
# 198  Slippers
# 199  Slippers
# 200  Slippers
# 201  Slippers
# 202  Slippers
# 203  Slippers
# 204  Slippers
# 205  Slippers
# 206  Slippers
# 207  Slippers
# 208  Slippers
# 209  Slippers

# %%
df_data = df_f.join(df_slippers)
df_data
# Out:
#          Type                                              Names  Prices
# 175  Slippers               Men Light Weight Soft Beach Slippers  371.16
# 176  Slippers          Men Non Slip Beach Casual Leather Sandals  336.03
# 177  Slippers           Men Clip Toe Soft Casual Beach Slippers   461.27
# 178  Slippers             Men Light Weight Casual Beach Slippers  336.03
# 179  Slippers            Men Stylish Soft Casual Beach Slippers   574.90
# 180  Slippers               Men Light Weight Soft Beach Slippers  461.27
# 181  Slippers        UREVOUREVO Flip Flops Summer Beach Slippers  184.74
# 182  Slippers            Men Light Weight Casual Beach Slippers   250.97
# 183  Slippers                    Men Water Beach Soft Flip Flops  312.16
# 184  Slippers            Men Colorful Printing Graffiti Slippers  483.96
# 185  Slippers               Men Colorful Printing Beach Slippers  478.58
# 186  Slippers      Men Colorful Printing Graffiti Beach Slippers  490.01
# ...

# %%
df_data.index.name='ID'

# %%
df_data.to_csv('Slippers.csv')
